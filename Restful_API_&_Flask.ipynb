# %%
#1 What is Restful API.
''' Restful is an architectural style  for designing web services that allow two software applications to communicate over the internet using HTTP protocol.
It is most common standard for modern web and mobile application backends due to its simplicity and ease of use.'''
# Out:
# ' Restful is an architectural style  for designing web services that allow two software applications to communicate over the internet using HTTP protocol.\nIt is most common standard for modern web and mobile application backends due to its simplicity and ease of use.'

# %%
#2  What is flask and why is it popular for building APIs.
'''Flask is lightweight "microframework" that provides tools, libraries and technologies to build web applications.
It is designed to provide maximum flexibility and simplicity for developers to build web applications.
It is popular for building APIs because it is easy to learn and use.'''
# Out:
# 'Flask is lightweight "microframework" that provides tools, libraries and technologies to build web applications.\nIt is designed to provide maximum flexibility and simplicity for developers to build web applications.\nIt is popular for building APIs because it is easy to learn and use.'

# %%
#3 What are HTTP methods used in Restful API.
'''GET, POST, PUT, DELETE are the HTTP methods used in Restful API.They typically represent the different operations that can be performed on a resource.'''
# Out:
# 'GET, POST, PUT, DELETE are the HTTP methods used in Restful API.They typically represent the different operations that can be performed on a resource.'

# %%
#4 What is the purpose of @app.rout() decorator in flask.
'''the @app.route() decorator in Flask is used to define a route for the application.It is used to map a URL to a Python function that will be executed when the URL is requested.'''
# Out:
# 'the @app.route() decorator in Flask is used to define a route for the application.It is used to map a URL to a Python function that will be executed when the URL is requested.'

# %%
#5 What is a role of Flask-SQLAlchemy.
'''Flask-SQLAlchemy is an extension that provides a Python object-relational mapping (ORM) for SQLAlchemy.It provides an Object Relational Mapper (ORM) that allows developers to easily interact with databases using Python objects.'''
# Out:
# 'Flask-SQLAlchemy is an extension that provides a Python object-relational mapping (ORM) for SQLAlchemy.It provides an Object Relational Mapper (ORM) that allows developers to easily interact with databases using Python objects.'

# %%
#6 How do you create a basic Flask application.
'''To create a basic Flask:
1. Install Flask: pip install flask
2. Create a new Python file and import Flask
3.Define a route using @app.route()
4.Run the application using app.run()'''
# Out:
# 'To create a basic Flask:\n1. Install Flask: pip install flask\n2. Create a new Python file and import Flask\n3.Define a route using @app.route()\n4.Run the application using app.run()'

# %%
#7 How do you return JSON  responses in Flask.
'''You use the jsonify() function to return JSON responses in Flask.It converts a python dictionary or list to a JSON object.'''
# Out:
# 'You use the jsonify() function to return JSON responses in Flask.It converts a python dictionary or list to a JSON object.'

# %%
#8 How do you handle POST  requests in FLASK.
'''To handle POST requests in Flask, you use the request object.
1.Specify the method in decorator :
@app.route('/login', methods=['POST'])
2.Access the form data :
username = request.form['username']
password = request.form['password']
3.Validate the data :
if not username or not password:
return jsonify({'error': 'Missing username or password'}), 400 '''
# Out:
# "To handle POST requests in Flask, you use the request object.\n1.Specify the method in decorator :\n@app.route('/login', methods=['POST'])\n2.Access the form data :\nusername = request.form['username']\npassword = request.form['password']\n3.Validate the data :\nif not username or not password:\nreturn jsonify({'error': 'Missing username or password'}), 400 "

# %%
#9 How do you handle errors in Flask (e.g 404).
'''To handle errors in Flask, you can use the errorhandler decorator.you pass the error code as an argument to the decorator.you pass the error code as an argument to the decorator.
@app.errorhandler(404) to the decorator and define a function to handle the error.The function should return a response object with the error message and status code.'''
# Out:
# 'To handle errors in Flask, you can use the errorhandler decorator.you pass the error code as an argument to the decorator.you pass the error code as an argument to the decorator.\n@app.errorhandler(404) to the decorator and define a function to handle the error.The function should return a response object with the error message and status code.'

# %%
#10 How do you structure Flask app using using Blueprints.
'''Flask Blueprints are a way to organize a flask application into modular, reusable components.
A blueprint is a Python object that contains the application's routes and other components.You define the routes in a blueprint, then register it with the application using the register_blueprint() method.'''
# Out:
# "Flask Blueprints are a way to organize a flask application into modular, reusable components.\nA blueprint is a Python object that contains the application's routes and other components.You define the routes in a blueprint, then register it with the application using the register_blueprint() method."
